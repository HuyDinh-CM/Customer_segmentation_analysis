# %% [markdown]
# ### Customer Segmentation analysis
# ### Overview:
# - During the Analysis Approach phase, using Python and Google Colab, I explored and cleaned the data in the "NewCustomerList" sheet.
#
# - By examining and processing missing values, null values, duplicates, and data inconsistency, I created the correct data set and prepared it for the next steps of analysis in the Customer Segmentation Analysis project.

# %% [markdown]
# ### Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

from datetime import datetime, date
plt.style.use('ggplot')

# %%
# Loading the Customer Demographics Data from the excel file
new_customer = pd.read_excel('Raw_data.xlsx' , sheet_name='NewCustomerList')
# Out:
# <ipython-input-3-f25ebe0db4e3>:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   new_customer = pd.read_excel('Raw_data.xlsx' , sheet_name='NewCustomerList')

# %%
new_customer.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
# Information of columns and data-types of Customer Demographics Data.
new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %% [markdown]
# The data form of the feature columns is good and consistent. But columns named 'unnamed: 16', 'unnamed: 17', 'unnamed: 18', 'unnamed: 19', and 'unnamed: 20' are irrelevant and unnecessary. They should be removed from the dataset.

# %%
print("Total records (rows) in the dataset : {}".format(new_customer.shape[0]))
print("Total columns (features) in the dataset : {}".format(new_customer.shape[1]))
# Out:
# Total records (rows) in the dataset : 1000
# Total columns (features) in the dataset : 23

# %% [markdown]
# ### Numeric Columns and Non-Numeric Columns

# %%
# select numeric columns
df_numeric = new_customer.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print("The numeric columns are : {}".format(numeric_cols))


# select non-numeric columns
df_non_numeric = new_customer.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print("The non-numeric columns are : {}".format(non_numeric_cols))
# Out:
# The numeric columns are : ['past_3_years_bike_related_purchases' 'tenure' 'postcode'
#  'property_valuation' 'Unnamed: 16' 'Unnamed: 17' 'Unnamed: 18'
#  'Unnamed: 19' 'Unnamed: 20' 'Rank' 'Value']
# The non-numeric columns are : ['first_name' 'last_name' 'gender' 'DOB' 'job_title'
#  'job_industry_category' 'wealth_segment' 'deceased_indicator' 'owns_car'
#  'address' 'state' 'country']

# %% [markdown]
# ### Dropping Irrelevent Columns

# %%
new_customer.drop(labels=['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'], axis=1 , inplace=True)

# %% [markdown]
# ### Missing Values Check

# %% [markdown]
# #### Overview about missing values

# %%
# Total number of missing values
new_customer.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
#Percentage of missing values
new_customer.isnull().mean()*100
# Out:
# first_name                              0.0
# last_name                               2.9
# gender                                  0.0
# past_3_years_bike_related_purchases     0.0
# DOB                                     1.7
# job_title                              10.6
# job_industry_category                  16.5
# wealth_segment                          0.0
# deceased_indicator                      0.0
# owns_car                                0.0
# tenure                                  0.0
# address                                 0.0
# postcode                                0.0
# state                                   0.0
# country                                 0.0
# property_valuation                      0.0
# Rank                                    0.0
# Value                                   0.0
# dtype: float64

# %% [markdown]
# Here the columns show the percentage of missing values from high to low, including columns such as:
# - job_industry_category (16.5%)
# - job_title (10.6%)
# - last_name (2.9%)
# - DOB (1.7%)

# %% [markdown]
# #### 1: job_industry_category

# %%
new_customer[new_customer['job_industry_category'].isnull()]
# Out:
#     first_name last_name  gender  past_3_years_bike_related_purchases  \
# 22        Otis     Ottey    Male                                   26
# 23    Tabbatha   Averill  Female                                    5
# 33       Mikel    McNess    Male                                   71
# 36      Farlie   Petford    Male                                   76
# 43     Corinna    Suggey  Female                                   52
# ..         ...       ...     ...                                  ...
# 959   Blondell   Dibdall  Female                                   62
# 971     Frieda   Tavinor  Female                                   43
# 975       Amby    Bodega    Male                                   63
# 980       Tyne   Anshell  Female                                   71
# 983    Augusta     Munns  Female                                    5
#
#            DOB                    job_title job_industry_category  \
# ...

# %%
new_customer['job_industry_category'].fillna('Missing', inplace=True, axis=0)

# %%
new_customer['job_industry_category'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 2: job_tiltle

# %%
new_customer[new_customer['job_title'].isnull()]
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 15       Dukie      Swire    Male                                   88
# 25      Rourke   Gillbard    Male                                   11
# 29       Rhona  De Freyne  Female                                   45
# 30     Sharron  Claibourn  Female                                   62
# 37    Mitchell   MacCague    Male                                   58
# ..         ...        ...     ...                                  ...
# 952      Candy        NaN  Female                                   23
# 953      Noami      Cokly  Female                                   74
# 971     Frieda    Tavinor  Female                                   43
# 972    Ellwood     Budden    Male                                   82
# 989     Kellen   Pawelski  Female                                   83
#
#            DOB job_title job_industry_category     wealth_segment  \
# ...

# %%
new_customer['job_title'].fillna('Missing', inplace=True, axis=0)

# %%
new_customer['job_title'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 3: last_name

# %%
new_customer[new_customer['last_name'].isnull()][['first_name']].isnull().sum()
# Out:
# first_name    0
# dtype: int64

# %%
new_customer[new_customer['last_name'].isnull()]
# Out:
#      first_name last_name  gender  past_3_years_bike_related_purchases  \
# 12         Olag       NaN    Male                                   60
# 58    Whittaker       NaN    Male                                   64
# 87     Kahaleel       NaN    Male                                    5
# 155        Bill       NaN  Female                                   74
# 202        Glyn       NaN    Male                                   47
# 326     Haleigh       NaN  Female                                   17
# 330        Alon       NaN    Male                                   17
# 357        Otis       NaN    Male                                   59
# 419     Sherill       NaN  Female                                   33
# 442   Theresina       NaN  Female                                   30
# 455     Laurena       NaN  Female                                   21
# 474      Laurie       NaN    Male                                   31
# ...

# %%
new_customer['last_name'].fillna('None',axis=0, inplace=True)

# %%
new_customer['last_name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 4: DOB

# %%
new_customer[new_customer['DOB'].isnull()]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 59       Normy     Goodinge      U                                    5 NaT
# 226      Hatti     Carletti      U                                   35 NaT
# 324   Rozamond       Turtle      U                                   69 NaT
# 358      Tamas      Swatman      U                                   65 NaT
# 360      Tracy   Andrejevic      U                                   71 NaT
# 374     Agneta      McAmish      U                                   66 NaT
# 434      Gregg      Aimeric      U                                   52 NaT
# 439      Johna       Bunker      U                                   93 NaT
# 574    Harlene         Nono      U                                   69 NaT
# 598   Gerianne       Kaysor      U                                   15 NaT
# 664     Chicky      Sinclar      U                                   43 NaT
# ...

# %%
round(new_customer['DOB'].isnull().mean()*100)
# Out:
# 2

# %%
dob_index_drop = new_customer[new_customer['DOB'].isnull()].index
dob_index_drop
# Out:
# Int64Index([ 59, 226, 324, 358, 360, 374, 434, 439, 574, 598, 664, 751, 775,
#             835, 883, 904, 984],
#            dtype='int64')

# %%
new_customer.drop(index=dob_index_drop, inplace=True, axis=0)

# %%
new_customer['DOB'].isnull().sum()
# Out:
# 0

# %%
# Function to calculate the age as of today based on the DOB of the customer.

def age(born):
    today = date.today()

    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

new_customer['Age'] = new_customer['DOB'].apply(age)

# %%
# Viz to find out the Age Distribution
plt.figure(figsize=(20,8))
sns.distplot(new_customer['Age'], kde=False, bins=50)
# Out:
# <ipython-input-34-d8f139ecec9a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_customer['Age'], kde=False, bins=50)
# <Axes: xlabel='Age'>

# %%
new_customer['Age'].describe()
# Out:
# count    983.000000
# mean      51.739573
# std       17.070279
# min       21.000000
# 25%       40.000000
# 50%       51.000000
# 75%       65.000000
# max       85.000000
# Name: Age, dtype: float64

# %%
new_customer['Age_Group'] = new_customer['Age'].apply(lambda x : (math.floor(x/10)+1)*10)

# %%
# Viz to find out the Age Group Distribution
plt.figure(figsize=(10,8))
sns.distplot(new_customer['Age_Group'], kde=False, bins=50)
# Out:
# <ipython-input-43-b1ffb437dd71>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_customer['Age_Group'], kde=False, bins=50)
# <Axes: xlabel='Age_Group'>

# %% [markdown]
# The number of new customers is mostly in the age group of 50-70 years old

# %% [markdown]
# ### Finally, Check if the entire dataset is missing or null values

# %%
new_customer.isnull().sum()
# Out:
# first_name                             0
# last_name                              0
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# address                                0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# Age                                    0
# Age_Group                              0
# dtype: int64

# %%
print("Total records after removing Missing Values: {}".format(new_customer.shape[0]))
# Out:
# Total records after removing Missing Values: 983

# %% [markdown]
# ### Check the inconsistency of the data
# The columns to be checked are 'gender', 'wealth_segment' ,'deceased_indicator', 'owns_car', 'state', 'country', 'adress, 'postcode', 'tenure'

# %% [markdown]
# #### 1: gender

# %%
new_customer['gender'].value_counts()
# Out:
# Female    513
# Male      470
# Name: gender, dtype: int64

# %% [markdown]
# #### 2: wealth_segment

# %%
new_customer['wealth_segment'].value_counts()
# Out:
# Mass Customer        499
# High Net Worth       249
# Affluent Customer    235
# Name: wealth_segment, dtype: int64

# %% [markdown]
# #### 3: deceased_indicator

# %%
new_customer['deceased_indicator'].value_counts()
# Out:
# N    983
# Name: deceased_indicator, dtype: int64

# %% [markdown]
# #### 4: owns_car

# %%
new_customer['owns_car'].value_counts()
# Out:
# No     497
# Yes    486
# Name: owns_car, dtype: int64

# %% [markdown]
# #### 5: state

# %%
new_customer['state'].value_counts()
# Out:
# NSW    499
# VIC    258
# QLD    226
# Name: state, dtype: int64

# %% [markdown]
# #### 6: country

# %%
new_customer['country'].value_counts()
# Out:
# Australia    983
# Name: country, dtype: int64

# %% [markdown]
# #### 7: address

# %%
new_customer['address'].value_counts()
# Out:
# 45 Shopko Center             1
# 7 Beilfuss Road              1
# 7 Elgar Hill                 1
# 36506 Bartillon Point        1
# 8 Scott Drive                1
#                             ..
# 2941 Talisman Alley          1
# 990 Hoffman Avenue           1
# 5 Summer Ridge Court         1
# 102 Charing Cross Terrace    1
# 21875 Grover Drive           1
# Name: address, Length: 983, dtype: int64

# %% [markdown]
# #### 8: postcode

# %%
new_customer['postcode'].value_counts()
# Out:
# 2232    9
# 2145    9
# 2750    7
# 2168    7
# 3029    7
#        ..
# 3919    1
# 3142    1
# 3047    1
# 4116    1
# 4215    1
# Name: postcode, Length: 515, dtype: int64

# %% [markdown]
# #### 9: tenure

# %%
new_customer['tenure'].describe()
# Out:
# count    983.000000
# mean      11.459817
# std        5.006123
# min        1.000000
# 25%        8.000000
# 50%       11.000000
# 75%       15.000000
# max       22.000000
# Name: tenure, dtype: float64

# %% [markdown]
# ### Sort values from dataset follow state

# %%
new_customer[['address', 'postcode','state','country']].sort_values('state')
# Out:
#                   address  postcode state    country
# 999    21875 Grover Drive      2010   NSW  Australia
# 392         02 Roth Drive      2022   NSW  Australia
# 391       4669 Troy Place      2207   NSW  Australia
# 720    43030 Carberry Way      2560   NSW  Australia
# 389  540 Forest Run Plaza      2168   NSW  Australia
# ..                    ...       ...   ...        ...
# 805     2 Namekagon Trail      3981   VIC  Australia
# 270     667 Waxwing Plaza      3199   VIC  Australia
# 275    655 Glendale Trail      3976   VIC  Australia
# 809      602 Clove Center      3046   VIC  Australia
# 594      9 Forster Circle      3174   VIC  Australia
#
# [983 rows x 4 columns]

# %% [markdown]
# ### Duplication Checks
# - We need to ensure that there is no duplication of records in the dataset. This may lead to error in data analysis due to poor data quality. If there are duplicate rows of data then we need to drop such records.
# - For checking for duplicate records we need to firstly remove the primary key column of the dataset then apply drop_duplicates() function provided by Python.

# %%
new_customer_dedupped = new_customer.drop_duplicates()

print("Number of records after removing customer_id (pk), duplicates : {}".format(new_customer_dedupped .shape[0]))
print("Number of records in original dataset : {}".format(new_customer.shape[0]))
# Out:
# Number of records after removing customer_id (pk), duplicates : 983
# Number of records in original dataset : 983

# %% [markdown]
# ### Exporting the Cleaned Customer Demographic Data Set to csv

# %%
new_customer.to_csv('NewCustomer_Cleaned.csv', index=False)
